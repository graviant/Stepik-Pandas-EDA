# %%
# Чтобы внести изменения в чужой репозиторий нужно сделать Fork
# pip (или conda) - пакетный менеджер, управляет зависимостями, удаление/установка/выгрузка
# Linter - инструмент для поиска и анализа ошибок (black)
# GIL - блокиратор потоков python
# builtins.py - системное пространство имён (системная область видимости). ОВ бывают: Системная -> Глобальная -> Охватывающая (Enclosing. Внутри внешней функции, но используется во внутренней, т.е. в ПОДфункции) -> Локальная (внутри функции).

# %%
# Декоратор - это функция, которая принимает функцию и возвращает функцию.
# Передача аргументов в функцию бывает - позиционная и ключевая.
# *args - распаковка позиционных аргументов, **kwargs - распаковка ключевых аргументов.

# %%
# ООП держится на 3х китах - инкапсуляция, полиморфизм, наследование. Все классы неявно наследуются от object.
# методы и атрибуты в классе - это функции и переменные соответственно
# метод void не результирующий, т.е. ничего не возвращает.

# %%
# class создается для объединения функций одного характера, а могли бы создать функцию если код программы был бы небольшой.
# Дандер методы (магические методы) вызываются автоматом при наступлении определенного события.

# %%
# Найти зависимости классов и методов можно, например, print(pd.DataFrame.__module__) -> выведет -> pandas.core.frame
